# %% [markdown]
# # Grundlagen der KI - Gruppenprojekte
#
#
# Für die Projekte stellen wir eine MongoDB Datenbank, die wir aktiv in der Forschung nutzen, zur Verfügung. Die Datenbank beinhaltet Informationen über Versionskontrollsysteme, Issuetracker, und Mailinglisten von Open Source Projekten. [Die Dokumentation der Datenbank finden Sie Online](https://smartshark2.informatik.uni-goettingen.de/documentation/).
#
# ## Die Aufgabe
#
# Ihre Aufgabe ist es, einen automatisierten Ansatz zu entwickeln, welcher vorhersagt, ob ein Issue innerhalb von 6 Monaten behoben wird oder nicht. Darüber hinaus, sollte das Modell (oder auch ein zweites Modell) in der Lage sein, die erwartete Zeit für die Behebung und damit Schließung des Issues vorherzusagen.
# Sie können dazu beliebige Informationen aus der Datenbank nutzen, wie z.B. Commits, andere Issues, Mails und Änderungen in den Dateien.
# Sie müssen diese Problemstellung als Analyseproblem fassen um dann Modelle zur Lösung aufstellen zu können. Hierzu müssen Sie geeignete Analysemethoden auswählen und anschließend die Qualität der Ergebnisse evaluieren.
#
# ## Präsentationen
#
# **Alle Gruppen müssen ihre Ergebnisse in der letzten Vorlesung am 09.02. um 16:15 Uhr vorstellen.** Hierzu muss jede Gruppe eine kurze Präsentation halten. In dieser Präsentation sollten Sie kurz beschreiben wie Sie vorgegangen sind, wie Sie Features erstellt haben, welche Modelle Sie benutzt haben und was ihre wichtigsten Ergebnisse sind. Die Zeit für die Präsentation beträgt 9 (1) Minuten.
#
# Im Anschluss an die Präsentation stimmen die Anwesenden über das beste Projekt ab. Jede Gruppe stimmt für das beste Projekt (3 Punkte), das zweitbeste (2 Punkte) und das drittbeste (1 Punkt). Das Projekt mit den meisten Punkten gewinnt einen Preis.
#
# Die Präsentation wird in Präsenz stattfinden, wenn die aktuellen Regeln es zulassen (Prof. Herbold wird dabei per Video zugeschaltet sein; Raum wird noch bekannt gegeben). Da wir nur begrenzt Zeit haben, müssen alle Präsentationen vorab geschickt werden. Wir kombinieren diese dann in einer PDF um einen einfachen Wechsel zwischen den Präsentation der Gruppen zu erreichen. Die Mitglieder der Gruppe werden dann in der Reihenfolge des Gruppennames gebeten ihre Ergebnisse vorzustellen, d.h. wir beginnen mit Gruppe 1 und enden mit Gruppe 6.
#
#
# ## Abgabe der Präsentationen
#
# Damit die Präsentation reibungslos ablaufen, müssen Sie ihre Präsentation im Vorfeld einsenden. **Schicken Sie Ihre Präsentationen bitte bis spätestens zum 08.02.23, 16 Uhr an Clemens Dierks via Email (clemens.dierks@tu-clausthal.de)**. Die Präsentation muss als PDF vorliegen.
#
#
# ## Mindestkriterien
#
# Die folgenden Kriterien muss ein Projekt mindestens erfüllen, damit die Gruppenmitglieder an der Prüfung teilnehmen können.
# - Es muss ein Modell für die automatisierte Vorhersage, ob ein Issue innerhalb von 6 Monaten gelöst wird, vorhanden sein.
# - Es muss ein Modell für die automatisierte Vorhersage der estimated-time-to-fix von Issues vorhanden sein.
# - Die Qualität des Modells muss bewertet werden.
# - Sie müssen eine Empfehlung geben, ob und ggf. unter welchen Umständen, das Modell eingesetzt werden kann basierend auf der Evaluation der Qualität des Modells.
# - Aufgrund Ihrer Empfehlung können Sie noch Verbesserungsmöglichkeiten vorstellen.
# - Die Ergebnisse müssen in der Vorlesung am 09.02.23 vorgestellt werden.
#
# ## Datenbankzugriff
#
# Unterhalb finden Sie ein Beispiel, wie Sie auf die Datenbank zugreifen. Die Datenbank befindet sich hinter einer Firewall und kann nur aus dem Netz der TU Clausthal erreicht werden. Wenn Sie Probleme haben die Datenbank zu erreichen, können Sie von jedem beliebigen Netzwerk aus in das Netz der TU Clausthal gelangen, in dem Sie sich mit dem [VPN](https://doku.tu-clausthal.de/doku.php?id=netzwerk_und_internet:vpn:start) verbinden.
#
# **WARNUNG:
# Wir benutzen die Datenbank aktiv in der Forschung. Es kann daher sein, das teilweise eine sehr hohe Last auf der Datenbank ist. Die Datenbank ist sehr groß und beinhaltet derzeit 4.8 Terabyte an Daten. Sie sollten daher nicht einfach starten Anfragen zu schreiben, sondern sich genau überlegen auf welche Informationen Sie zugreifen wollen. Wenn Sie zum Beispiel eine Anfrage stellen, in der Sie die komplette ```commit``` Collection herunterladen möchten, müssen Sie hierfür 158 Gigabyte an Daten runterladen. **
#
# Sie können die Bibliothek [pycoSHARK](https://github.com/smartshark/pycoshark) zum Zugriff auf die Datenbank nutzen. Der pycoSHARK stellt einen ORM-Layer basierend auf der Bibliothek ```mongoengine``` zur Verfügung. Hierdurch können Sie die Datenbanktabellen wie Objekte behandeln. Alternativ können Sie die native MongoDB API der ```pymongo``` Bibliothek benutzen.
#
# Der Quelltext unten beinhaltet Ihre Zugangsdaten in zeigt wie man mit dem pycoSHARK auf die Datenbank zugreift.

# %%
Interesting features: No. of commits of the issue creator,age of the branch,

# %%
# Installation des pycoSHARKs
import sys
# !{sys.executable} -m pip install pycoshark

# %%
from mongoengine import connect, disconnect
from pycoshark.mongomodels import File, FileAction, Commit, Project, VCSSystem, IssueSystem,Hunk, Refactoring, IssueSystem, Issue, IssueComment, MailingList, Message
from pycoshark.utils import create_mongodb_uri_string
import pandas as pd
from pandas_profiling import ProfileReport
# Database credentials
user = 'grundlagenki2021'
password = '38BTGx71d'
host = '134.76.81.151'
port = '27017'
authentication_db = 'smartshark'
database = "smartshark"
ssl_enabled = None

# Establish connection
uri = create_mongodb_uri_string(user, password, host, port, authentication_db, ssl_enabled)
connect(database, host=uri)

# Fetch project id and issue tracking system system id for the 'commons-math' project
# The only() decides the data that is actually retrieved from the MongoDB. 
# get() only works, when you query results in exactly one document, otherwise you have to use a loop to access the data
# an example with a loop is at the bottom of this example
project = Project.objects(name='commons-math').only('id').get()
issue_system = IssueSystem.objects(project_id=project.id).only('id','url').get()
print('url of issue system of the project: %s' % issue_system.url)
# Out:
# url of issue system of the project: https://issues.apache.org/jira/rest/api/2/search?jql=project=MATH

# %% [markdown]
# Copied from https://github.com/smartshark/usage-examples/blob/main/Example-Notebook.ipynb:

# %%
# We first need the the project from the database
project = Project.objects(name='giraph').get()

# We now select the issue tracking system of the project
# Please note that some projects have multiple issue trackers
# In this case get() would fail and you would need to loop over them
issue_tracker = IssueSystem.objects(project_id=project.id).get()

print('Issue Tracker:', issue_tracker.url)

# we can now work with the issues
num_issues = Issue.objects(issue_system_id=issue_tracker.id).count()

print('Number of issues:', num_issues)

count_comments = 0
count_referenced_by_commits = 0
count_bugs_dev_label = 0
count_bugs_validated = 0

for issue in Issue.objects(issue_system_id=issue_tracker.id):
    count_comments += IssueComment.objects(issue_id=issue.id).count()
    if issue.issue_type is not None and issue.issue_type.lower()=='bug':
        count_bugs_dev_label += 1
    if issue.issue_type_verified is not None and issue.issue_type_verified.lower()=='bug':
        count_bugs_validated += 1
    if Commit.objects(linked_issue_ids=issue.id).count()>0:
        count_referenced_by_commits += 1
        
print('Number of comments in discussions:', count_comments)
print('Number of issues referenced by commits:', count_referenced_by_commits)
print('Number of issues labeled as bugs by developers:', count_bugs_dev_label)
print('Number of issues labeled validated as bug by researchers:', count_bugs_validated)
# Out:
# Issue Tracker: https://issues.apache.org/jira/rest/api/2/search?jql=project=GIRAPH
# Number of issues: 1232
# Number of comments in discussions: 6759
# Number of issues referenced by commits: 787
# Number of issues labeled as bugs by developers: 534
# Number of issues labeled validated as bug by researchers: 140

# %%
for items in Project.objects:
    print (items.name)
# Out:
# commons-math
# oisafe
# ant-ivy
# junit
# kafka
# zeppelin
# mahout
# struts
# opennlp
# pig
# calcite
# cayenne
# falcon
# kylin
# nutch
# parquet-mr
# tika
# wss4j
# archiva
# deltaspike
# jspwiki
# xerces2-j
# tez
# systemml
# storm
# lens
# accumulo
# commons-lang
# james
# pdfbox
# flume
# nifi
# knox
# derby
# commons-collections
# commons-beanutils
# commons-codec
# commons-compress
# commons-configuration
# commons-digester
# commons-imaging
# commons-io
# commons-jcs
# commons-jexl
# commons-rdf
# commons-scxml
# commons-validator
# commons-vfs
# giraph
# manifoldcf
# ranger
# eagle
# commons-bcel
# commons-dbcp
# zookeeper
# phoenix
# gora
# santuario-java
# helix
# jena
# httpcomponents-client
# commons-net
# httpcomponents-core
# streams
# samza
# roller
# mina-sshd
# bigtop
# jackrabbit
# tomcat
# rhino
# oozie
# avro
# activemq
# fop
# maven
# airavata
# openjpa
# AutoUpdater.NET
# directory-fortress-core
# eShopOnWeb
# EquinoxProject
# BlazorWithIdentity
# ruler
# quick-picture-viewer
# Mynt
# SuperSafeBank
# Hunt
# Windows-appsample-networkhelper
# Windows-appsample-customers-orders-database
# Miniblog.Core
# coolstore-microservices
# clean-architecture-manga
# StarWars
# openmeetings
# asterixdb
# directory-studio
# activemq-artemis
# xmlgraphics-batik
# curator
# directory-kerby
# directory-server
# fineract
# cxf-fediz
# freemarker
# openwebbeans
# tapestry-5
# reef
# tinkerpop
# juddi
# velocity-engine
# velocity-tools
# karaf-cellar
# maven-archetype
# maven-doxia
# maven-scm
# maven-surefire
# maven-wagon
# oodt
# portals-pluto
# qpid-jms
# sis
# uima-ducc
# usergrid
# poi
# isis

# %%
# We first need the the project from the database
project = Project.objects(name='commons-math').get()

# We now select the issue tracking system of the project
# Please note that some projects have multiple issue trackers
# In this case get() would fail and you would need to loop over them
issue_tracker = IssueSystem.objects(project_id=project.id).get()
df=pd.read_json(Issue.objects(issue_system_id=issue_tracker.id).to_json())

# %%
df.head()
# Out:
#                                     _id external_id  \
# 0  {'$oid': '58c11cfc11e1802cacc2a8a0'}     AAR-185
# 1  {'$oid': '58c11cfd11e1802cacc2a8c0'}   COMPLEX-4
# 2  {'$oid': '58c1186d11e1802cacc26584'}    MATH-147
# 3  {'$oid': '58c1187411e1802cacc265b6'}      MATH-2
# 4  {'$oid': '58c1188011e1802cacc2660a'}     MATH-14
#
#                         issue_system_id affects_versions components labels  \
# 0  {'$oid': '58c1131c537f8c637a3d5529'}               []         []     []
# 1  {'$oid': '58c1131c537f8c637a3d5529'}               []         []     []
# 2  {'$oid': '58c1131c537f8c637a3d5529'}            [1.0]         []     []
# 3  {'$oid': '58c1131c537f8c637a3d5529'}               []         []     []
# 4  {'$oid': '58c1131c537f8c637a3d5529'}               []         []     []
#
#   fix_versions issue_links                                              title  \
# 0           []          []                                                NaN
# 1           []          []                                                NaN
# 2        [1.0]          []                   Adding new methods to RealMatrix
# 3           []          []  [math] fixed some javadoc and checkstyle warnings
# 4           []          []                 [patch] Gamma.logGamma performance
#
#                                                 desc  ...   issue_type  \
# 0                                                NaN  ...          NaN
# 1                                                NaN  ...          NaN
# 2  /*\n * Copyright 2003-2004 The Apache Software...  ...  Improvement
# 3                                                     ...          Bug
# 4  I did some profiling on a project and found a ...  ...          Bug
#
#   priority  status resolution                               environment  \
# 0      NaN     NaN        NaN                                       NaN
# 1      NaN     NaN        NaN                                       NaN
# 2    Minor  Closed      Fixed      Operating System: All\nPlatform: All
# 3    Major  Closed      Fixed  Operating System: other\nPlatform: Other
# 4    Major  Closed      Fixed      Operating System: All\nPlatform: All
#
#                                    issue_type_manual issue_type_verified  \
# 0                                                NaN                 NaN
# 1                                                NaN                 NaN
# 2                                                NaN                 NaN
# 3  {'sherbold': 'improvement', 'ftrautsch': 'impr...         improvement
# 4                                                NaN                 NaN
#
#   assignee_id original_time_estimate parent_issue_id
# 0         NaN                    NaN             NaN
# 1         NaN                    NaN             NaN
# 2         NaN                    NaN             NaN
# 3         NaN                    NaN             NaN
# 4         NaN                    NaN             NaN
#
# [5 rows x 24 columns]

# %%
ProfileReport(df, title="Pandas Profiling Report")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 ProfileReport(df, title="Pandas Profiling Report")
#
# File ~\anaconda3\envs\KI\lib\site-packages\IPython\core\displayhook.py:262, in DisplayHook.__call__(self, result)
#     260 self.start_displayhook()
#     261 self.write_output_prompt()
# --> 262 format_dict, md_dict = self.compute_format_data(result)
#     263 self.update_user_ns(result)
#     264 self.fill_exec_result(result)
#
# File ~\anaconda3\envs\KI\lib\site-packages\IPython\core\displayhook.py:151, in DisplayHook.compute_format_data(self, result)
#     121 def compute_format_data(self, result):
#     122     """Compute format data of the object to be displayed.
#     123
#     124     The format data is a generalization of the :func:`repr` of an object.
#    (...)
#     149
#     150     """
# --> 151     return self.shell.display_formatter.format(result)
#
# File ~\anaconda3\envs\KI\lib\site-packages\IPython\core\formatters.py:177, in DisplayFormatter.format(self, obj, include, exclude)
#     175 md = None
#     176 try:
# --> 177     data = formatter(obj)
#     178 except:
#     179     # FIXME: log the exception
#     180     raise
#
# File ~\anaconda3\envs\KI\lib\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~\anaconda3\envs\KI\lib\site-packages\IPython\core\formatters.py:221, in catch_format_error(method, self, *args, **kwargs)
#     219 """show traceback on failed format call"""
#     220 try:
# --> 221     r = method(self, *args, **kwargs)
#     222 except NotImplementedError:
#     223     # don't warn on NotImplementedErrors
#     224     return self._check_return(None, args[0])
#
# File ~\anaconda3\envs\KI\lib\site-packages\IPython\core\formatters.py:342, in BaseFormatter.__call__(self, obj)
#     340     method = get_real_method(obj, self.print_method)
#     341     if method is not None:
# --> 342         return method()
#     343     return None
#     344 else:
#
# File ~\anaconda3\envs\KI\lib\site-packages\typeguard\__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File ~\anaconda3\envs\KI\lib\site-packages\pandas_profiling\profile_report.py:470, in ProfileReport._repr_html_(self)
#     468 def _repr_html_(self) -> None:
#     469     """The ipython notebook widgets user interface gets called by the jupyter notebook."""
# --> 470     self.to_notebook_iframe()
#
# File ~\anaconda3\envs\KI\lib\site-packages\typeguard\__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File ~\anaconda3\envs\KI\lib\site-packages\pandas_profiling\profile_report.py:450, in ProfileReport.to_notebook_iframe(self)
#     448 with warnings.catch_warnings():
#     449     warnings.simplefilter("ignore")
# --> 450     display(get_notebook_iframe(self.config, self))
#
# File ~\anaconda3\envs\KI\lib\site-packages\pandas_profiling\report\presentation\flavours\widget\notebook.py:75, in get_notebook_iframe(config, profile)
#      73     output = get_notebook_iframe_src(config, profile)
#      74 elif attribute == IframeAttribute.srcdoc:
# ---> 75     output = get_notebook_iframe_srcdoc(config, profile)
#      76 else:
#      77     raise ValueError(
#      78         f'Iframe Attribute can be "src" or "srcdoc" (current: {attribute}).'
#      79     )
#
# File ~\anaconda3\envs\KI\lib\site-packages\pandas_profiling\report\presentation\flavours\widget\notebook.py:29, in get_notebook_iframe_srcdoc(config, profile)
#      27 width = config.notebook.iframe.width
#      28 height = config.notebook.iframe.height
# ---> 29 src = html.escape(profile.to_html())
#      31 iframe = f'<iframe width="{width}" height="{height}" srcdoc="{src}" frameborder="0" allowfullscreen></iframe>'
#      33 return HTML(iframe)
#
# File ~\anaconda3\envs\KI\lib\site-packages\typeguard\__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File ~\anaconda3\envs\KI\lib\site-packages\pandas_profiling\profile_report.py:420, in ProfileReport.to_html(self)
#     412 def to_html(self) -> str:
#     413     """Generate and return complete template as lengthy string
#     414         for using with frameworks.
#     415
#    (...)
#     418
#     419     """
# --> 420     return self.html
#
# File ~\anaconda3\envs\KI\lib\site-packages\typeguard\__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File ~\anaconda3\envs\KI\lib\site-packages\pandas_profiling\profile_report.py:231, in ProfileReport.html(self)
#     228 @property
#     229 def html(self) -> str:
#     230     if self._html is None:
# --> 231         self._html = self._render_html()
#     232     return self._html
#
# File ~\anaconda3\envs\KI\lib\site-packages\typeguard\__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File ~\anaconda3\envs\KI\lib\site-packages\pandas_profiling\profile_report.py:339, in ProfileReport._render_html(self)
#     336 def _render_html(self) -> str:
#     337     from pandas_profiling.report.presentation.flavours import HTMLReport
# --> 339     report = self.report
#     341     with tqdm(
#     342         total=1, desc="Render HTML", disable=not self.config.progress_bar
#     343     ) as pbar:
#     344         html = HTMLReport(copy.deepcopy(report)).render(
#     345             nav=self.config.html.navbar_show,
#     346             offline=self.config.html.use_local_assets,
#    (...)
#     354             version=self.description_set["package"]["pandas_profiling_version"],
#     355         )
#
# File ~\anaconda3\envs\KI\lib\site-packages\typeguard\__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File ~\anaconda3\envs\KI\lib\site-packages\pandas_profiling\profile_report.py:225, in ProfileReport.report(self)
#     222 @property
#     223 def report(self) -> Root:
#     224     if self._report is None:
# --> 225         self._report = get_report_structure(self.config, self.description_set)
#     226     return self._report
#
# File ~\anaconda3\envs\KI\lib\site-packages\pandas_profiling\report\structure\report.py:381, in get_report_structure(config, summary)
#     364 section_items: List[Renderable] = [
#     365     Container(
#     366         get_dataset_items(config, summary, alerts),
#    (...)
#     370     ),
#     371 ]
#     373 if len(summary["variables"]) > 0:
#     374     section_items.append(
#     375         Dropdown(
#     376             name="Variables",
#     377             anchor_id="variables-dropdown",
#     378             id="variables-dropdown",
#     379             items=list(summary["variables"]),
#     380             item=Container(
# --> 381                 render_variables_section(config, summary),
#     382                 sequence_type="accordion",
#     383                 name="Variables",
#     384                 anchor_id="variables",
#     385             ),
#     386         )
#     387     )
#     389 scatter_items = get_interactions(config, summary["scatter"])
#     390 if len(scatter_items) > 0:
#
# File ~\anaconda3\envs\KI\lib\site-packages\pandas_profiling\report\structure\report.py:159, in render_variables_section(config, dataframe_summary)
#     157     variable_type = summary["type"]
#     158 render_map_type = render_map.get(variable_type, render_map["Unsupported"])
# --> 159 template_variables.update(render_map_type(config, template_variables))
#     161 # Ignore these
#     162 if reject_variables:
#
# File ~\anaconda3\envs\KI\lib\site-packages\pandas_profiling\report\structure\variables\render_categorical.py:407, in render_categorical(config, summary)
#     404 overview_items = []
#     406 if length:
# --> 407     length_table, length_histo = render_categorical_length(config, summary, varid)
#     408     overview_items.append(length_table)
#     410 if characters:
#
# File ~\anaconda3\envs\KI\lib\site-packages\pandas_profiling\report\structure\variables\render_categorical.py:96, in render_categorical_length(config, summary, varid)
#      90     hist_data = histogram(
#      91         config,
#      92         [x[0] for x in summary["histogram_length"]],
#      93         [x[1] for x in summary["histogram_length"]],
#      94     )
#      95 else:
# ---> 96     hist_data = histogram(config, *summary["histogram_length"])
#      98 length_histo = Image(
#      99     hist_data,
#     100     image_format=config.plot.image_format,
#    (...)
#     104     anchor_id=f"{varid}length",
#     105 )
#     107 return length_table, length_histo
#
# File ~\anaconda3\envs\KI\lib\contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File ~\anaconda3\envs\KI\lib\site-packages\pandas_profiling\visualisation\plot.py:124, in histogram(config, series, bins, date)
#     122 plot.xaxis.set_tick_params(rotation=90 if date else 45)
#     123 plot.figure.tight_layout()
# --> 124 return plot_360_n0sc0pe(config)
#
# File ~\anaconda3\envs\KI\lib\site-packages\pandas_profiling\visualisation\utils.py:73, in plot_360_n0sc0pe(config, image_format, bbox_extra_artists, bbox_inches)
#      70 if image_format == "svg":
#      71     image_str = StringIO()
# ---> 73     plt.savefig(
#      74         image_str,
#      75         format=image_format,
#      76         bbox_extra_artists=bbox_extra_artists,
#      77         bbox_inches=bbox_inches,
#      78     )
#      79     plt.close()
#      80     result_string = image_str.getvalue()
#
# File ~\anaconda3\envs\KI\lib\site-packages\matplotlib\pyplot.py:960, in savefig(*args, **kwargs)
#     958 fig = gcf()
#     959 res = fig.savefig(*args, **kwargs)
# --> 960 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#     961 return res
#
# File ~\anaconda3\envs\KI\lib\site-packages\matplotlib\backend_bases.py:2054, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2052 if not self._is_idle_drawing:
#    2053     with self._idle_draw_cntx():
# -> 2054         self.draw(*args, **kwargs)
#
# File ~\anaconda3\envs\KI\lib\site-packages\matplotlib\backends\backend_agg.py:405, in FigureCanvasAgg.draw(self)
#     401 # Acquire a lock on the shared font cache.
#     402 with RendererAgg.lock, \
#     403      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     404       else nullcontext()):
# --> 405     self.figure.draw(self.renderer)
#     406     # A GUI class may be need to update a window using this draw, so
#     407     # don't forget to call the superclass.
#     408     super().draw()
#
# File ~\anaconda3\envs\KI\lib\site-packages\matplotlib\artist.py:74, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      72 @wraps(draw)
#      73 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74     result = draw(artist, renderer, *args, **kwargs)
#      75     if renderer._rasterizing:
#      76         renderer.stop_rasterizing()
#
# File ~\anaconda3\envs\KI\lib\site-packages\matplotlib\artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\envs\KI\lib\site-packages\matplotlib\figure.py:3082, in Figure.draw(self, renderer)
#    3079         # ValueError can occur when resizing a window.
#    3081 self.patch.draw(renderer)
# -> 3082 mimage._draw_list_compositing_images(
#    3083     renderer, self, artists, self.suppressComposite)
#    3085 for sfig in self.subfigs:
#    3086     sfig.draw(renderer)
#
# File ~\anaconda3\envs\KI\lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File ~\anaconda3\envs\KI\lib\site-packages\matplotlib\artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\envs\KI\lib\site-packages\matplotlib\axes\_base.py:3100, in _AxesBase.draw(self, renderer)
#    3097         a.draw(renderer)
#    3098     renderer.stop_rasterizing()
# -> 3100 mimage._draw_list_compositing_images(
#    3101     renderer, self, artists, self.figure.suppressComposite)
#    3103 renderer.close_group('axes')
#    3104 self.stale = False
#
# File ~\anaconda3\envs\KI\lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File ~\anaconda3\envs\KI\lib\site-packages\matplotlib\artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\envs\KI\lib\site-packages\matplotlib\axis.py:1308, in Axis.draw(self, renderer, *args, **kwargs)
#    1305 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1307 for tick in ticks_to_draw:
# -> 1308     tick.draw(renderer)
#    1310 # Scale up the axis label box to also find the neighbors, not just the
#    1311 # tick labels that actually overlap.  We need a *copy* of the axis
#    1312 # label box because we don't want to scale the actual bbox.
#    1314 self._update_label_position(renderer)
#
# File ~\anaconda3\envs\KI\lib\site-packages\matplotlib\artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\envs\KI\lib\site-packages\matplotlib\axis.py:306, in Tick.draw(self, renderer)
#     303 renderer.open_group(self.__name__, gid=self.get_gid())
#     304 for artist in [self.gridline, self.tick1line, self.tick2line,
#     305                self.label1, self.label2]:
# --> 306     artist.draw(renderer)
#     307 renderer.close_group(self.__name__)
#     308 self.stale = False
#
# File ~\anaconda3\envs\KI\lib\site-packages\matplotlib\artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\envs\KI\lib\site-packages\matplotlib\text.py:735, in Text.draw(self, renderer)
#     731             textrenderer.draw_tex(gc, x, y, clean_line,
#     732                                   self._fontproperties, angle,
#     733                                   mtext=mtext)
#     734         else:
# --> 735             textrenderer.draw_text(gc, x, y, clean_line,
#     736                                    self._fontproperties, angle,
#     737                                    ismath=ismath, mtext=mtext)
#     739 gc.restore()
#     740 renderer.close_group('text')
#
# File ~\anaconda3\envs\KI\lib\site-packages\matplotlib\backends\backend_agg.py:207, in RendererAgg.draw_text(self, gc, x, y, s, prop, angle, ismath, mtext)
#     204 font = self._prepare_font(prop)
#     205 # We pass '0' for angle here, since it will be rotated (in raster
#     206 # space) in the following call to draw_text_image).
# --> 207 font.set_text(s, 0, flags=get_hinting_flag())
#     208 font.draw_glyphs_to_bitmap(
#     209     antialiased=mpl.rcParams['text.antialiased'])
#     210 d = font.get_descent() / 64.0
#
# KeyboardInterrupt:

# %% [markdown]
# sort out not matching repositories:

# %%
extid='MATH' #2Do: obtain the correct external_id for each repository to sort out invalid issues or logs
df[~df.external_id.str.startswith(extid)]
# Out:
#                                        _id external_id  \
# 0     {'$oid': '58c11cfc11e1802cacc2a8a0'}     AAR-185
# 1     {'$oid': '58c11cfd11e1802cacc2a8c0'}   COMPLEX-4
# 155   {'$oid': '58c1194411e1802cacc26fc0'}    LANG-663
# 417   {'$oid': '58c11cfd11e1802cacc2a8be'}   NUMBERS-4
# 1405  {'$oid': '59bc19b8eb89781003facf95'}  NUMBERS-15
# 1413  {'$oid': '59bc1a0ceb89781003fad039'}  NUMBERS-31
# 1414  {'$oid': '59bc1a0feb89781003fad056'}  NUMBERS-22
# 1416  {'$oid': '59bc1a13eb89781003fad07c'}  NUMBERS-32
# 1417  {'$oid': '59bc1a14eb89781003fad086'}  NUMBERS-19
# 1418  {'$oid': '59bc1a17eb89781003fad0a0'}  NUMBERS-36
#
#                            issue_system_id affects_versions components labels  \
# 0     {'$oid': '58c1131c537f8c637a3d5529'}               []         []     []
# 1     {'$oid': '58c1131c537f8c637a3d5529'}               []         []     []
# 155   {'$oid': '58c1131c537f8c637a3d5529'}               []         []     []
# 417   {'$oid': '58c1131c537f8c637a3d5529'}               []         []     []
# 1405  {'$oid': '58c1131c537f8c637a3d5529'}               []         []     []
# 1413  {'$oid': '58c1131c537f8c637a3d5529'}               []         []     []
# 1414  {'$oid': '58c1131c537f8c637a3d5529'}               []         []     []
# 1416  {'$oid': '58c1131c537f8c637a3d5529'}               []         []     []
# 1417  {'$oid': '58c1131c537f8c637a3d5529'}               []         []     []
# 1418  {'$oid': '58c1131c537f8c637a3d5529'}               []         []     []
#
#      fix_versions issue_links title desc  ... issue_type priority status  \
# 0              []          []   NaN  NaN  ...        NaN      NaN    NaN
# 1              []          []   NaN  NaN  ...        NaN      NaN    NaN
# 155            []          []   NaN  NaN  ...        NaN      NaN    NaN
# 417            []          []   NaN  NaN  ...        NaN      NaN    NaN
# 1405           []          []   NaN  NaN  ...        NaN      NaN    NaN
# 1413           []          []   NaN  NaN  ...        NaN      NaN    NaN
# 1414           []          []   NaN  NaN  ...        NaN      NaN    NaN
# 1416           []          []   NaN  NaN  ...        NaN      NaN    NaN
# 1417           []          []   NaN  NaN  ...        NaN      NaN    NaN
# 1418           []          []   NaN  NaN  ...        NaN      NaN    NaN
#
#      resolution environment issue_type_manual issue_type_verified assignee_id  \
# 0           NaN         NaN               NaN                 NaN         NaN
# 1           NaN         NaN               NaN                 NaN         NaN
# 155         NaN         NaN               NaN                 NaN         NaN
# 417         NaN         NaN               NaN                 NaN         NaN
# 1405        NaN         NaN               NaN                 NaN         NaN
# 1413        NaN         NaN               NaN                 NaN         NaN
# 1414        NaN         NaN               NaN                 NaN         NaN
# 1416        NaN         NaN               NaN                 NaN         NaN
# 1417        NaN         NaN               NaN                 NaN         NaN
# 1418        NaN         NaN               NaN                 NaN         NaN
#
#      original_time_estimate parent_issue_id
# 0                       NaN             NaN
# 1                       NaN             NaN
# 155                     NaN             NaN
# 417                     NaN             NaN
# 1405                    NaN             NaN
# 1413                    NaN             NaN
# 1414                    NaN             NaN
# 1416                    NaN             NaN
# 1417                    NaN             NaN
# 1418                    NaN             NaN
#
# [10 rows x 24 columns]

# %%
df1=df
df1['created_at']=pd.json_normalize(df1['created_at'])
df1['updated_at']=pd.json_normalize(df1['updated_at'])

df1['timetofix']=df1.updated_at-df1.created_at

# %%
df1
# Out:
#                                        _id  external_id  \
# 0     {'$oid': '5bf58b8b423c98412cd404c9'}   INFRA-3855
# 1     {'$oid': '5bf58b8b423c98412cd404ca'}     GIRAPH-1
# 2     {'$oid': '5bf58b8c423c98412cd404dc'}     GIRAPH-9
# 3     {'$oid': '5bf58b8d423c98412cd404e6'}     GIRAPH-7
# 4     {'$oid': '5bf58b8e423c98412cd404ea'}    GIRAPH-29
# ...                                    ...          ...
# 1227  {'$oid': '5bf5905f423c98412cd43d5d'}   GIRAPH-448
# 1228  {'$oid': '5bf59060423c98412cd43d64'}   GIRAPH-689
# 1229  {'$oid': '5bf59061423c98412cd43d69'}    GIRAPH-42
# 1230  {'$oid': '5bf59062423c98412cd43d7d'}   GIRAPH-646
# 1231  {'$oid': '5bf59064423c98412cd43d88'}  GIRAPH-1211
#
#                            issue_system_id affects_versions   components  \
# 0     {'$oid': '5bf58b88423c98412cd404c8'}               []           []
# 1     {'$oid': '5bf58b88423c98412cd404c8'}          [0.1.0]           []
# 2     {'$oid': '5bf58b88423c98412cd404c8'}               []           []
# 3     {'$oid': '5bf58b88423c98412cd404c8'}               []           []
# 4     {'$oid': '5bf58b88423c98412cd404c8'}               []        [bsp]
# ...                                    ...              ...          ...
# 1227  {'$oid': '5bf58b88423c98412cd404c8'}          [0.1.0]  [mapreduce]
# 1228  {'$oid': '5bf58b88423c98412cd404c8'}               []           []
# 1229  {'$oid': '5bf58b88423c98412cd404c8'}          [0.1.0]        [bsp]
# 1230  {'$oid': '5bf58b88423c98412cd404c8'}               []      [graph]
# 1231  {'$oid': '5bf58b88423c98412cd404c8'}               []           []
#
#                labels fix_versions  \
# 0                  []           []
# 1                  []      [0.1.0]
# 2                  []      [0.1.0]
# 3                  []           []
# 4                  []      [0.1.0]
# ...               ...          ...
# 1227               []           []
# 1228               []           []
# 1229  [newbie, patch]           []
# 1230               []           []
# 1231               []           []
#
#                                             issue_links  \
# 0                                                    []
# 1     [{'issue_id': {'$oid': '5bf58b8b423c98412cd404...
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 1227                                                 []
# 1228                                                 []
# 1229                                                 []
# 1230                                                 []
# 1231                                                 []
#
#                                                   title  \
# 0                                                   NaN
# 1                                   Initial code import
# 2     Change Yahoo License Header to Apache License ...
# 3               Remove Yahoo-specific code from pom.xml
# 4     Implement TextVertexInputFormat for text-forma...
# ...                                                 ...
# 1227                    orphan process left on DataNode
# 1228  Add Label Propagation for community detection ...
# 1229  The MapReduce counter 'Sent Messages' doesn't ...
# 1230  In the DefaultVertexResolver, rename the creat...
# 1231  Make retrying to send network requests after t...
#
#                                                    desc  ...  priority  \
# 0                                                   NaN  ...       NaN
# 1            I did the initial code import from github.  ...     Major
# 2     All source codes contains Yahoo License Header...  ...     Major
# 3     There are remaining references to Y! infrastru...  ...   Blocker
# 4     Supporting text-format graph data would be nic...  ...     Minor
# ...                                                 ...  ...       ...
# 1227  I am able to run some simple Graph job success...  ...     Major
# 1228  Label propagation is a community detection alg...  ...     Major
# 1229  The MapReduce counter 'Sent Messages' doesn't ...  ...     Minor
# 1230                  Typo: Vertexes should be Vertices  ...   Trivial
# 1231  Using counters added in GIRAPH-1205 we were ab...  ...     Major
#
#         status resolution                           assignee_id  \
# 0          NaN        NaN                                   NaN
# 1     Resolved      Fixed  {'$oid': '5b3b302830a71b06bc515831'}
# 2     Resolved      Fixed  {'$oid': '5b48554530a71b06bcb992b0'}
# 3     Resolved  Duplicate  {'$oid': '5b3b3d6230a71b06bc84d07f'}
# 4     Resolved  Won't Fix  {'$oid': '5b48554530a71b06bcb992b0'}
# ...        ...        ...                                   ...
# 1227  Resolved      Fixed                                   NaN
# 1228  Resolved  Won't Fix                                   NaN
# 1229  Resolved      Fixed                                   NaN
# 1230  Resolved      Fixed                                   NaN
# 1231      Open        NaN  {'$oid': '5bf58c4d35e3ea2b7b0fb474'}
#
#                                       issue_type_manual issue_type_verified  \
# 0                                                   NaN                 NaN
# 1                                                   NaN                 NaN
# 2     {'sherbold': 'other', 'atrautsch': 'documentat...               other
# 3                                                   NaN                 NaN
# 4                                                   NaN                 NaN
# ...                                                 ...                 ...
# 1227                                                NaN                 NaN
# 1228                                                NaN                 NaN
# 1229                                                NaN                 NaN
# 1230                                                NaN                 NaN
# 1231                                                NaN                 NaN
#
#                           environment original_time_estimate parent_issue_id  \
# 0                                 NaN                    NaN             NaN
# 1                                 NaN                    NaN             NaN
# 2                                 NaN                    NaN             NaN
# 3                                 NaN                    NaN             NaN
# 4                                 NaN                    NaN             NaN
# ...                               ...                    ...             ...
# 1227  Hadoop 1.0 with Fedora linux OS                    NaN             NaN
# 1228                              NaN                    NaN             NaN
# 1229                              NaN                    NaN             NaN
# 1230                              NaN                    NaN             NaN
# 1231                              NaN                    NaN             NaN
#
#          timetofix
# 0              NaN
# 1     4.720466e+08
# 2     1.472391e+07
# 3     9.642159e+08
# 4     1.830291e+07
# ...            ...
# 1227  1.864427e+11
# 1228  1.706224e+11
# 1229  2.245930e+11
# 1230  1.754117e+11
# 1231  2.263965e+08
#
# [1232 rows x 25 columns]

# %%
good=df1.query('status=="Resolved" and timetofix<15780000')
good
# Out:
#                                        _id  external_id  \
# 2     {'$oid': '5bf58b8c423c98412cd404dc'}     GIRAPH-9
# 5     {'$oid': '5bf58b8f423c98412cd404f1'}    GIRAPH-33
# 8     {'$oid': '5bf58b90423c98412cd40505'}    GIRAPH-46
# 10    {'$oid': '5bf58b92423c98412cd40511'}    GIRAPH-59
# 20    {'$oid': '5bf58b9b423c98412cd40594'}    GIRAPH-71
# ...                                    ...          ...
# 911   {'$oid': '5bf58f2d423c98412cd432ec'}   GIRAPH-932
# 947   {'$oid': '5bf58f4e423c98412cd43466'}   GIRAPH-958
# 949   {'$oid': '5bf58f50423c98412cd43470'}   GIRAPH-960
# 994   {'$oid': '5bf58f81423c98412cd435ec'}  GIRAPH-1097
# 1122  {'$oid': '5bf58ff7423c98412cd439cf'}  GIRAPH-1143
#
#                            issue_system_id affects_versions components labels  \
# 2     {'$oid': '5bf58b88423c98412cd404c8'}               []         []     []
# 5     {'$oid': '5bf58b88423c98412cd404c8'}               []    [graph]     []
# 8     {'$oid': '5bf58b88423c98412cd404c8'}          [0.1.0]         []     []
# 10    {'$oid': '5bf58b88423c98412cd404c8'}          [0.1.0]         []     []
# 20    {'$oid': '5bf58b88423c98412cd404c8'}          [0.1.0]      [lib]     []
# ...                                    ...              ...        ...    ...
# 911   {'$oid': '5bf58b88423c98412cd404c8'}               []         []     []
# 947   {'$oid': '5bf58b88423c98412cd404c8'}          [1.1.0]    [build]     []
# 949   {'$oid': '5bf58b88423c98412cd404c8'}               []         []     []
# 994   {'$oid': '5bf58b88423c98412cd404c8'}          [1.2.0]         []     []
# 1122  {'$oid': '5bf58b88423c98412cd404c8'}               []         []     []
#
#      fix_versions issue_links  \
# 2         [0.1.0]          []
# 5         [0.1.0]          []
# 8         [0.1.0]          []
# 10        [0.1.0]          []
# 20        [0.1.0]          []
# ...           ...         ...
# 911            []          []
# 947       [1.1.0]          []
# 949            []          []
# 994       [1.2.0]          []
# 1122           []          []
#
#                                                   title  \
# 2     Change Yahoo License Header to Apache License ...
# 5             Missing license header of GraphState.java
# 8     Race condition on superstep 1 with RPC servers...
# 10    test is debug enabled before LOG.debug(), so a...
# 20    SequenceFileVertexInputFormat missing license ...
# ...                                                 ...
# 911                       Add Arcanist suport to Giraph
# 947         .arcconfig needs to be added to rat exclude
# 949            Max task attempts should be 1 and not 0.
# 994    Fix TestOutOfCore.testOutOfCoreLocalDiskAccessor
# 1122   org.apache.hadoop.mapreduce.JobID.forName job...
#
#                                                    desc  ...  priority  \
# 2     All source codes contains Yahoo License Header...  ...     Major
# 5     GraphState.java doesn't contain apache license...  ...   Trivial
# 8     Hi,\n\noccasionally (maybe one time in four), ...  ...     Minor
# 10    For example: src/main/java/org/apache/giraph/c...  ...     Minor
# 20    SequenceFileVertexInputFormat needs the Apache...  ...     Major
# ...                                                 ...  ...       ...
# 911                  We have one more code review tool!  ...     Major
# 947                       Trivial fix to make rat happy  ...   Trivial
# 949                 https://reviews.facebook.net/D27579  ...     Major
# 994   TestOutOfCore.testOutOfCoreLocalDiskAccessor f...  ...     Major
# 1122                                                NaN  ...   Trivial
#
#         status resolution                           assignee_id  \
# 2     Resolved      Fixed  {'$oid': '5b48554530a71b06bcb992b0'}
# 5     Resolved      Fixed                                   NaN
# 8     Resolved      Fixed  {'$oid': '5bf58b8b35e3ea2b7b0f9147'}
# 10    Resolved      Fixed  {'$oid': '5bf58b9235e3ea2b7b0f9232'}
# 20    Resolved      Fixed  {'$oid': '5b3b3d6230a71b06bc84d07f'}
# ...        ...        ...                                   ...
# 911   Resolved      Fixed  {'$oid': '5bf58b8b35e3ea2b7b0f9147'}
# 947   Resolved      Fixed  {'$oid': '5b29fbb730a71b06bcf54976'}
# 949   Resolved      Fixed  {'$oid': '5bf58b8b35e3ea2b7b0f9147'}
# 994   Resolved      Fixed  {'$oid': '5bf58e8335e3ea2b7b101d08'}
# 1122  Resolved      Fixed  {'$oid': '5bf58b8b35e3ea2b7b0f9147'}
#
#                                       issue_type_manual issue_type_verified  \
# 2     {'sherbold': 'other', 'atrautsch': 'documentat...               other
# 5                                                   NaN                 NaN
# 8               {'ftrautsch': 'bug', 'sherbold': 'bug'}                 bug
# 10    {'ftrautsch': 'improvement', 'sherbold': 'impr...         improvement
# 20    {'ftrautsch': 'improvement', 'sherbold': 'othe...               other
# ...                                                 ...                 ...
# 911                                                 NaN                 NaN
# 947   {'ftrautsch': 'improvement', 'sherbold': 'othe...               other
# 949   {'ftrautsch': 'improvement', 'sherbold': 'bug'...                 bug
# 994           {'ftrautsch': 'test', 'sherbold': 'test'}                test
# 1122            {'ftrautsch': 'bug', 'sherbold': 'bug'}                 bug
#
#      environment original_time_estimate parent_issue_id   timetofix
# 2            NaN                    NaN             NaN  14723906.0
# 5            NaN                    NaN             NaN  12489855.0
# 8            NaN                    NaN             NaN   1168600.0
# 10           NaN                    NaN             NaN   7087743.0
# 20           NaN                    NaN             NaN   2249441.0
# ...          ...                    ...             ...         ...
# 911          NaN                    NaN             NaN   5574823.0
# 947          NaN                    NaN             NaN   6286424.0
# 949          NaN                    NaN             NaN   3810453.0
# 994          NaN                    NaN             NaN  11988902.0
# 1122         NaN                    NaN             NaN   3622402.0
#
# [61 rows x 25 columns]

# %%
bad=df1.query('status!="Resolved" or timetofix>15780000')
bad
# Out:
#                                        _id  external_id  \
# 0     {'$oid': '5bf58b8b423c98412cd404c9'}   INFRA-3855
# 1     {'$oid': '5bf58b8b423c98412cd404ca'}     GIRAPH-1
# 3     {'$oid': '5bf58b8d423c98412cd404e6'}     GIRAPH-7
# 4     {'$oid': '5bf58b8e423c98412cd404ea'}    GIRAPH-29
# 6     {'$oid': '5bf58b90423c98412cd404f9'}    GIRAPH-12
# ...                                    ...          ...
# 1227  {'$oid': '5bf5905f423c98412cd43d5d'}   GIRAPH-448
# 1228  {'$oid': '5bf59060423c98412cd43d64'}   GIRAPH-689
# 1229  {'$oid': '5bf59061423c98412cd43d69'}    GIRAPH-42
# 1230  {'$oid': '5bf59062423c98412cd43d7d'}   GIRAPH-646
# 1231  {'$oid': '5bf59064423c98412cd43d88'}  GIRAPH-1211
#
#                            issue_system_id affects_versions   components  \
# 0     {'$oid': '5bf58b88423c98412cd404c8'}               []           []
# 1     {'$oid': '5bf58b88423c98412cd404c8'}          [0.1.0]           []
# 3     {'$oid': '5bf58b88423c98412cd404c8'}               []           []
# 4     {'$oid': '5bf58b88423c98412cd404c8'}               []        [bsp]
# 6     {'$oid': '5bf58b88423c98412cd404c8'}              NaN        [bsp]
# ...                                    ...              ...          ...
# 1227  {'$oid': '5bf58b88423c98412cd404c8'}          [0.1.0]  [mapreduce]
# 1228  {'$oid': '5bf58b88423c98412cd404c8'}               []           []
# 1229  {'$oid': '5bf58b88423c98412cd404c8'}          [0.1.0]        [bsp]
# 1230  {'$oid': '5bf58b88423c98412cd404c8'}               []      [graph]
# 1231  {'$oid': '5bf58b88423c98412cd404c8'}               []           []
#
#                labels fix_versions  \
# 0                  []           []
# 1                  []      [0.1.0]
# 3                  []           []
# 4                  []      [0.1.0]
# 6                 NaN      [0.1.0]
# ...               ...          ...
# 1227               []           []
# 1228               []           []
# 1229  [newbie, patch]           []
# 1230               []           []
# 1231               []           []
#
#                                             issue_links  \
# 0                                                    []
# 1     [{'issue_id': {'$oid': '5bf58b8b423c98412cd404...
# 3                                                    []
# 4                                                    []
# 6     [{'issue_id': {'$oid': '5bf58b90423c98412cd404...
# ...                                                 ...
# 1227                                                 []
# 1228                                                 []
# 1229                                                 []
# 1230                                                 []
# 1231                                                 []
#
#                                                   title  \
# 0                                                   NaN
# 1                                   Initial code import
# 3               Remove Yahoo-specific code from pom.xml
# 4     Implement TextVertexInputFormat for text-forma...
# 6                Investigate communication improvements
# ...                                                 ...
# 1227                    orphan process left on DataNode
# 1228  Add Label Propagation for community detection ...
# 1229  The MapReduce counter 'Sent Messages' doesn't ...
# 1230  In the DefaultVertexResolver, rename the creat...
# 1231  Make retrying to send network requests after t...
#
#                                                    desc  ...  priority  \
# 0                                                   NaN  ...       NaN
# 1            I did the initial code import from github.  ...     Major
# 3     There are remaining references to Y! infrastru...  ...   Blocker
# 4     Supporting text-format graph data would be nic...  ...     Minor
# 6     Currently every worker will start up a thread ...  ...     Minor
# ...                                                 ...  ...       ...
# 1227  I am able to run some simple Graph job success...  ...     Major
# 1228  Label propagation is a community detection alg...  ...     Major
# 1229  The MapReduce counter 'Sent Messages' doesn't ...  ...     Minor
# 1230                  Typo: Vertexes should be Vertices  ...   Trivial
# 1231  Using counters added in GIRAPH-1205 we were ab...  ...     Major
#
#         status resolution                           assignee_id  \
# 0          NaN        NaN                                   NaN
# 1     Resolved      Fixed  {'$oid': '5b3b302830a71b06bc515831'}
# 3     Resolved  Duplicate  {'$oid': '5b3b3d6230a71b06bc84d07f'}
# 4     Resolved  Won't Fix  {'$oid': '5b48554530a71b06bcb992b0'}
# 6     Resolved      Fixed  {'$oid': '5b48554530a71b06bcb992b0'}
# ...        ...        ...                                   ...
# 1227  Resolved      Fixed                                   NaN
# 1228  Resolved  Won't Fix                                   NaN
# 1229  Resolved      Fixed                                   NaN
# 1230  Resolved      Fixed                                   NaN
# 1231      Open        NaN  {'$oid': '5bf58c4d35e3ea2b7b0fb474'}
#
#                                       issue_type_manual issue_type_verified  \
# 0                                                   NaN                 NaN
# 1                                                   NaN                 NaN
# 3                                                   NaN                 NaN
# 4                                                   NaN                 NaN
# 6     {'sherbold': 'improvement', 'atrautsch': 'impr...                 NaN
# ...                                                 ...                 ...
# 1227                                                NaN                 NaN
# 1228                                                NaN                 NaN
# 1229                                                NaN                 NaN
# 1230                                                NaN                 NaN
# 1231                                                NaN                 NaN
#
#                           environment original_time_estimate parent_issue_id  \
# 0                                 NaN                    NaN             NaN
# 1                                 NaN                    NaN             NaN
# 3                                 NaN                    NaN             NaN
# 4                                 NaN                    NaN             NaN
# 6                                 NaN                    NaN             NaN
# ...                               ...                    ...             ...
# 1227  Hadoop 1.0 with Fedora linux OS                    NaN             NaN
# 1228                              NaN                    NaN             NaN
# 1229                              NaN                    NaN             NaN
# 1230                              NaN                    NaN             NaN
# 1231                              NaN                    NaN             NaN
#
#          timetofix
# 0              NaN
# 1     4.720466e+08
# 3     9.642159e+08
# 4     1.830291e+07
# 6     2.439484e+10
# ...            ...
# 1227  1.864427e+11
# 1228  1.706224e+11
# 1229  2.245930e+11
# 1230  1.754117e+11
# 1231  2.263965e+08
#
# [1171 rows x 25 columns]
